# %%
import numpy as np
import pandas as pd
import os.path as op
from sklearn.feature_selection import SelectKBest, chi2
import pickle
from scipy.fft import fft, fftfreq
from tqdm import tqdm

# %%
def load_obj(name, path):
    with open(op.join(path, name), 'rb') as f:
        return pickle.load(f)

# %%
patients = ["25", "27", "38", "61", "83", "97", "18", "22", "54", "68", "69", "84", "105", "42", "20", "30", "11", "47", "56", "101", "117", "4", "8", "26", "66", "67", "79", "92", "111", "2", "24", "65", "73", "100", "118", "119", "23", "35","40", "62", "102", "107", "108", "109"]

# %%
patients_df = load_obj("preprocessed_data.pkl","/sps/crnl/ademasson/data/features_extraction")

# %%
patients_df.keys()
# Out:
# dict_keys(['X_25', 'y_25', 'X_27', 'y_27', 'X_38', 'y_38', 'X_61', 'y_61', 'X_83', 'y_83', 'X_97', 'y_97', 'X_18', 'y_18', 'X_22', 'y_22', 'X_54', 'y_54', 'X_68', 'y_68', 'X_69', 'y_69', 'X_84', 'y_84', 'X_105', 'y_105', 'X_42', 'y_42', 'X_20', 'y_20', 'X_30', 'y_30', 'X_11', 'y_11', 'X_47', 'y_47', 'X_56', 'y_56', 'X_101', 'y_101', 'X_117', 'y_117', 'X_4', 'y_4', 'X_8', 'y_8', 'X_26', 'y_26', 'X_66', 'y_66', 'X_67', 'y_67', 'X_79', 'y_79', 'X_92', 'y_92', 'X_111', 'y_111', 'X_2', 'y_2', 'X_24', 'y_24', 'X_65', 'y_65', 'X_73', 'y_73', 'X_100', 'y_100', 'X_118', 'y_118', 'X_119', 'y_119', 'X_23', 'y_23', 'X_35', 'y_35', 'X_40', 'y_40', 'X_62', 'y_62', 'X_102', 'y_102', 'X_107', 'y_107', 'X_108', 'y_108', 'X_109', 'y_109'])

# %%
list_of_features = ["ppa", "upslope", "downslope", "std", "amplitude_ratio", "sharpness", "average_slope", "main_frequency", "phase_congruency"]

# %%
cv = 5
patients_per_fold = len(patients) // cv

# %%
for i in tqdm(range(0,cv)):
    test_patients = patients[i*patients_per_fold:(i+1)*patients_per_fold]
    train_patients = patients[:i*patients_per_fold] + patients[(i+1)*patients_per_fold:]
    # Train sets
    X_train = None
    y_train = None
    for j, patient in enumerate(train_patients):
        X_patient_set = patients_df[f"X_{patient}"]
        y_patient_set = patients_df[f"y_{patient}"]
        if X_train is None:
            X_train = X_patient_set
        else:
            X_train = pd.concat([X_train, X_patient_set], axis=0, ignore_index=True)

        if y_train is None:
            y_train = y_patient_set
        else:
            y_train = np.hstack([y_train, y_patient_set])
            
    # Test sets
    X_test = None
    y_test = None
    for j, patient in enumerate(test_patients):
        X_patient_set = patients_df[f"X_{patient}"]
        y_patient_set = patients_df[f"y_{patient}"]             
        if X_test is None:
            X_test = X_patient_set
        else:
            X_test = pd.concat([X_test, X_patient_set], axis=0, ignore_index=True)

        if y_test is None:
            y_test = y_patient_set
        else:
            y_test = np.hstack([y_test, y_patient_set])
            
    
    # SelectKBest
    train_selector = SelectKBest(chi2, k=X_train.shape[1])
#     y_train[:] = y_train[:X_train.shape[1]]
    train_selector.fit_transform(X_train, y_train)
    train_feature_scores = {feature: train_selector.scores_[i] for i, feature in enumerate(X_train.columns)}
    train_feature_mean_scores = {}
    for feature in list_of_features:
        scores = []
        for col in X_train.columns:
            if col.startswith(feature):
                scores.append(train_feature_scores[col])
        train_feature_mean_scores[feature] = np.mean(scores)
    train_feature_mean_scores = {k: v for k, v in sorted(train_feature_mean_scores.items(), key=lambda x: x[1], reverse=True)}
    
    test_selector = SelectKBest(chi2, k=X_test.shape[1])
#     y_test[:] = y_test[:X_test.shape[1]]
    test_selector.fit_transform(X_test, y_test)
    test_feature_scores = {feature: test_selector.scores_[i] for i, feature in enumerate(X_test.columns)}
    test_feature_mean_scores = {}
    for feature in list_of_features:
        scores = []
        for col in X_test.columns:
            if col.startswith(feature):
                scores.append(test_feature_scores[col])
        test_feature_mean_scores[feature] = np.mean(scores)
    test_feature_mean_scores = {k: v for k, v in sorted(test_feature_mean_scores.items(), key=lambda x: x[1], reverse=True)}
    
    print("--------------------------")
    print(f"CV n° {i+1}")
    print("--------------------------")
    print("Feature scores on Train set : ")
    for k,v in train_feature_mean_scores.items():
        print(k + " : " + str(v/len(train_patients)))
    print("--------------------------")
    print("Feature scores on Test set : ")
    for k,v in test_feature_mean_scores.items():
        print(k + " : " + str(v/len(test_patients)))
    print("--------------------------")
# Out:
#  20%|██        | 1/5 [00:35<02:21, 35.28s/it]
# --------------------------
# CV n° 1
# --------------------------
# Feature scores on Train set :
# std : 3.3681694557346664
# ppa : 3.232113074059955
# average_slope : 1.3647151000114666
# upslope : 0.8210867292151032
# amplitude_ratio : 0.4713060574652315
# sharpness : 0.3781794495017944
# downslope : 0.26184123830906386
# main_frequency : 0.21286297738463808
# phase_congruency : 0.0020523560842613245
# --------------------------
# Feature scores on Test set :
# ppa : 2.2693674674026445
# std : 2.248466917205477
# amplitude_ratio : 1.2815445369252538
# average_slope : 1.0211687122046789
# upslope : 0.4922881798393459
# sharpness : 0.27112143652462084
# downslope : 0.2222036363232927
# main_frequency : 0.21078242557042165
# phase_congruency : 0.0034768899777414294
# --------------------------
#  40%|████      | 2/5 [01:11<01:46, 35.58s/it]
# --------------------------
# CV n° 2
# --------------------------
# Feature scores on Train set :
# std : 3.3193101294462006
# ppa : 3.2045893971541877
# average_slope : 1.2691743542937295
# upslope : 0.7312402182856631
# amplitude_ratio : 0.49921925992199134
# sharpness : 0.33764961858521114
# downslope : 0.24954010824991857
# main_frequency : 0.15361416113335186
# phase_congruency : 0.0018795697725526419
# --------------------------
# Feature scores on Test set :
# ppa : 2.564003056617864
# std : 2.5233106754195394
# average_slope : 1.6752904561973496
# upslope : 1.056674382479084
# amplitude_ratio : 0.6609594052268705
# sharpness : 0.63769582940431
# main_frequency : 0.40059128578476755
# downslope : 0.35366699494897536
# phase_congruency : 0.004077192844460162
# --------------------------
#  60%|██████    | 3/5 [01:46<01:11, 35.57s/it]
# --------------------------
# CV n° 3
# --------------------------
# Feature scores on Train set :
# std : 3.196156881041073
# ppa : 3.0057363395806
# average_slope : 1.057941739576991
# upslope : 0.5594011896748392
# amplitude_ratio : 0.5006490013062245
# sharpness : 0.2190831412520605
# main_frequency : 0.21783885542131343
# downslope : 0.19461281134263825
# phase_congruency : 0.00206702626240038
# --------------------------
# Feature scores on Test set :
# ppa : 3.348922897733546
# average_slope : 3.107679237585826
# std : 3.050060125340736
# upslope : 2.280955671369411
# sharpness : 1.880592862395085
# amplitude_ratio : 1.094148682040836
# downslope : 0.6770209338872232
# main_frequency : 0.2858040590341538
# phase_congruency : 0.004193896991734877
# --------------------------
#  80%|████████  | 4/5 [02:22<00:35, 35.68s/it]
# --------------------------
# CV n° 4
# --------------------------
# Feature scores on Train set :
# std : 3.444100176240592
# ppa : 3.290310964710928
# average_slope : 1.348808369382191
# upslope : 0.7393460393391756
# amplitude_ratio : 0.43201855149473867
# sharpness : 0.3127824558002643
# downslope : 0.2460166472051445
# main_frequency : 0.13381435465581515
# phase_congruency : 0.0017390400642625589
# --------------------------
# Feature scores on Test set :
# std : 2.752583780009679
# ppa : 2.5019244421901026
# amplitude_ratio : 1.6766717290876616
# average_slope : 1.5846081514063792
# upslope : 1.2031197774330606
# sharpness : 0.9821175064871133
# downslope : 0.4015792883767464
# main_frequency : 0.27152401807199555
# phase_congruency : 0.0046762271590830035
# --------------------------
# 100%|██████████| 5/5 [02:58<00:00, 35.61s/it]
# --------------------------
# CV n° 5
# --------------------------
# Feature scores on Train set :
# ppa : 2.446936169396782
# std : 2.4284765665230306
# average_slope : 1.5995981955815812
# upslope : 1.0726065965368
# sharpness : 0.7049184094660838
# downslope : 0.355725319000917
# amplitude_ratio : 0.25256020334120954
# main_frequency : 0.05669168604798975
# phase_congruency : 0.0012685640654564515
# --------------------------
# Feature scores on Test set :
# std : 7.314594997571441
# ppa : 6.857561930027476
# amplitude_ratio : 2.4875005739126133
# average_slope : 2.1711040234570667
# upslope : 1.2808898429536895
# main_frequency : 0.8370147326019971
# sharpness : 0.6021423294341738
# downslope : 0.38753877208121457
# phase_congruency : 0.0073509884843020335
# --------------------------

# %%
features_columns = {}

for feature in list_of_features:
    matching_columns = [col for col in patients_df['X_25'].columns if col.startswith(feature)]
    features_columns[feature] = matching_columns

# %%
list_of_features = ["std", "ppa", "average_slope", "upslope", "amplitude_ratio", "down_slope", "main_frequency", "phase_congruency"]

# %%
features_columns
# Out:
# {'ppa': ['ppa_Channel_1',
#   'ppa_Channel_2',
#   'ppa_Channel_3',
#   'ppa_Channel_4',
#   'ppa_Channel_5',
#   'ppa_Channel_6',
#   'ppa_Channel_7',
#   'ppa_Channel_8',
#   'ppa_Channel_9',
#   'ppa_Channel_10',
#   'ppa_Channel_11',
#   'ppa_Channel_12',
#   'ppa_Channel_13',
#   'ppa_Channel_14',
#   'ppa_Channel_15',
#   'ppa_Channel_16',
#   'ppa_Channel_17',
#   'ppa_Channel_18',
#   'ppa_Channel_19',
#   'ppa_Channel_20',
#   'ppa_Channel_21',
#   'ppa_Channel_22',
#   'ppa_Channel_23',
#   'ppa_Channel_24',
#   'ppa_Channel_25',
#   'ppa_Channel_26',
#   'ppa_Channel_27',
#   'ppa_Channel_28',
#   'ppa_Channel_29',
#   'ppa_Channel_30',
#   'ppa_Channel_31',
#   'ppa_Channel_32',
#   'ppa_Channel_33',
#   'ppa_Channel_34',
#   'ppa_Channel_35',
#   'ppa_Channel_36',
#   'ppa_Channel_37',
#   'ppa_Channel_38',
#   'ppa_Channel_39',
#   'ppa_Channel_40',
#   'ppa_Channel_41',
#   'ppa_Channel_42',
#   'ppa_Channel_43',
#   'ppa_Channel_44',
#   'ppa_Channel_45',
#   'ppa_Channel_46',
#   'ppa_Channel_47',
#   'ppa_Channel_48',
#   'ppa_Channel_49',
#   'ppa_Channel_50',
#   'ppa_Channel_51',
#   'ppa_Channel_52',
#   'ppa_Channel_53',
#   'ppa_Channel_54',
#   'ppa_Channel_55',
#   'ppa_Channel_56',
#   'ppa_Channel_57',
#   'ppa_Channel_58',
#   'ppa_Channel_59',
#   'ppa_Channel_60',
#   'ppa_Channel_61',
#   'ppa_Channel_62',
#   'ppa_Channel_63',
#   'ppa_Channel_64',
#   'ppa_Channel_65',
#   'ppa_Channel_66',
#   'ppa_Channel_67',
#   'ppa_Channel_68',
#   'ppa_Channel_69',
#   'ppa_Channel_70',
#   'ppa_Channel_71',
#   'ppa_Channel_72',
#   'ppa_Channel_73',
#   'ppa_Channel_74',
#   'ppa_Channel_75',
#   'ppa_Channel_76',
#   'ppa_Channel_77',
#   'ppa_Channel_78',
#   'ppa_Channel_79',
#   'ppa_Channel_80',
#   'ppa_Channel_81',
#   'ppa_Channel_82',
#   'ppa_Channel_83',
#   'ppa_Channel_84',
#   'ppa_Channel_85',
#   'ppa_Channel_86',
#   'ppa_Channel_87',
#   'ppa_Channel_88',
#   'ppa_Channel_89',
#   'ppa_Channel_90',
#   'ppa_Channel_91',
#   'ppa_Channel_92',
#   'ppa_Channel_93',
#   'ppa_Channel_94',
#   'ppa_Channel_95',
#   'ppa_Channel_96',
#   'ppa_Channel_97',
#   'ppa_Channel_98',
#   'ppa_Channel_99',
#   'ppa_Channel_100',
#   'ppa_Channel_101',
#   'ppa_Channel_102',
#   'ppa_Channel_103',
#   'ppa_Channel_104',
#   'ppa_Channel_105',
#   'ppa_Channel_106',
#   'ppa_Channel_107',
#   'ppa_Channel_108',
#   'ppa_Channel_109',
#   'ppa_Channel_110',
#   'ppa_Channel_111',
#   'ppa_Channel_112',
#   'ppa_Channel_113',
#   'ppa_Channel_114',
#   'ppa_Channel_115',
#   'ppa_Channel_116',
#   'ppa_Channel_117',
#   'ppa_Channel_118',
#   'ppa_Channel_119',
#   'ppa_Channel_120',
#   'ppa_Channel_121',
#   'ppa_Channel_122',
#   'ppa_Channel_123',
#   'ppa_Channel_124',
#   'ppa_Channel_125',
#   'ppa_Channel_126',
#   'ppa_Channel_127',
#   'ppa_Channel_128',
#   'ppa_Channel_129',
#   'ppa_Channel_130',
#   'ppa_Channel_131',
#   'ppa_Channel_132',
#   'ppa_Channel_133',
#   'ppa_Channel_134',
#   'ppa_Channel_135',
#   'ppa_Channel_136',
#   'ppa_Channel_137',
#   'ppa_Channel_138',
#   'ppa_Channel_139',
#   'ppa_Channel_140',
#   'ppa_Channel_141',
#   'ppa_Channel_142',
#   'ppa_Channel_143',
#   'ppa_Channel_144',
#   'ppa_Channel_145',
#   'ppa_Channel_146',
#   'ppa_Channel_147',
#   'ppa_Channel_148',
#   'ppa_Channel_149',
#   'ppa_Channel_150',
#   'ppa_Channel_151',
#   'ppa_Channel_152',
#   'ppa_Channel_153',
#   'ppa_Channel_154',
#   'ppa_Channel_155',
#   'ppa_Channel_156',
#   'ppa_Channel_157',
#   'ppa_Channel_158',
#   'ppa_Channel_159',
#   'ppa_Channel_160',
#   'ppa_Channel_161',
#   'ppa_Channel_162',
#   'ppa_Channel_163',
#   'ppa_Channel_164',
#   'ppa_Channel_165',
#   'ppa_Channel_166',
#   'ppa_Channel_167',
#   'ppa_Channel_168',
#   'ppa_Channel_169',
#   'ppa_Channel_170',
#   'ppa_Channel_171',
#   'ppa_Channel_172',
#   'ppa_Channel_173',
#   'ppa_Channel_174',
#   'ppa_Channel_175',
#   'ppa_Channel_176',
#   'ppa_Channel_177',
#   'ppa_Channel_178',
#   'ppa_Channel_179',
#   'ppa_Channel_180',
#   'ppa_Channel_181',
#   'ppa_Channel_182',
#   'ppa_Channel_183',
#   'ppa_Channel_184',
#   'ppa_Channel_185',
#   'ppa_Channel_186',
#   'ppa_Channel_187',
#   'ppa_Channel_188',
#   'ppa_Channel_189',
#   'ppa_Channel_190',
#   'ppa_Channel_191',
#   'ppa_Channel_192',
#   'ppa_Channel_193',
#   'ppa_Channel_194',
#   'ppa_Channel_195',
#   'ppa_Channel_196',
#   'ppa_Channel_197',
#   'ppa_Channel_198',
#   'ppa_Channel_199',
#   'ppa_Channel_200',
#   'ppa_Channel_201',
#   'ppa_Channel_202',
#   'ppa_Channel_203',
#   'ppa_Channel_204',
#   'ppa_Channel_205',
#   'ppa_Channel_206',
#   'ppa_Channel_207',
#   'ppa_Channel_208',
#   'ppa_Channel_209',
#   'ppa_Channel_210',
#   'ppa_Channel_211',
#   'ppa_Channel_212',
#   'ppa_Channel_213',
#   'ppa_Channel_214',
#   'ppa_Channel_215',
#   'ppa_Channel_216',
#   'ppa_Channel_217',
#   'ppa_Channel_218',
#   'ppa_Channel_219',
#   'ppa_Channel_220',
#   'ppa_Channel_221',
#   'ppa_Channel_222',
#   'ppa_Channel_223',
#   'ppa_Channel_224',
#   'ppa_Channel_225',
#   'ppa_Channel_226',
#   'ppa_Channel_227',
#   'ppa_Channel_228',
#   'ppa_Channel_229',
#   'ppa_Channel_230',
#   'ppa_Channel_231',
#   'ppa_Channel_232',
#   'ppa_Channel_233',
#   'ppa_Channel_234',
#   'ppa_Channel_235',
#   'ppa_Channel_236',
#   'ppa_Channel_237',
#   'ppa_Channel_238',
#   'ppa_Channel_239',
#   'ppa_Channel_240',
#   'ppa_Channel_241',
#   'ppa_Channel_242',
#   'ppa_Channel_243',
#   'ppa_Channel_244',
#   'ppa_Channel_245',
#   'ppa_Channel_246',
#   'ppa_Channel_247',
#   'ppa_Channel_248',
#   'ppa_Channel_249',
#   'ppa_Channel_250',
#   'ppa_Channel_251',
#   'ppa_Channel_252',
#   'ppa_Channel_253',
#   'ppa_Channel_254',
#   'ppa_Channel_255',
#   'ppa_Channel_256',
#   'ppa_Channel_257',
#   'ppa_Channel_258',
#   'ppa_Channel_259',
#   'ppa_Channel_260',
#   'ppa_Channel_261',
#   'ppa_Channel_262',
#   'ppa_Channel_263',
#   'ppa_Channel_264',
#   'ppa_Channel_265',
#   'ppa_Channel_266',
#   'ppa_Channel_267',
#   'ppa_Channel_268',
#   'ppa_Channel_269',
#   'ppa_Channel_270',
#   'ppa_Channel_271',
#   'ppa_Channel_272',
#   'ppa_Channel_273',
#   'ppa_Channel_274'],
#  'upslope': ['upslope_Channel_1',
#   'upslope_Channel_2',
#   'upslope_Channel_3',
#   'upslope_Channel_4',
#   'upslope_Channel_5',
#   'upslope_Channel_6',
#   'upslope_Channel_7',
#   'upslope_Channel_8',
#   'upslope_Channel_9',
#   'upslope_Channel_10',
#   'upslope_Channel_11',
#   'upslope_Channel_12',
#   'upslope_Channel_13',
#   'upslope_Channel_14',
#   'upslope_Channel_15',
#   'upslope_Channel_16',
#   'upslope_Channel_17',
#   'upslope_Channel_18',
#   'upslope_Channel_19',
#   'upslope_Channel_20',
#   'upslope_Channel_21',
#   'upslope_Channel_22',
#   'upslope_Channel_23',
#   'upslope_Channel_24',
#   'upslope_Channel_25',
#   'upslope_Channel_26',
#   'upslope_Channel_27',
#   'upslope_Channel_28',
#   'upslope_Channel_29',
#   'upslope_Channel_30',
#   'upslope_Channel_31',
#   'upslope_Channel_32',
#   'upslope_Channel_33',
#   'upslope_Channel_34',
#   'upslope_Channel_35',
#   'upslope_Channel_36',
#   'upslope_Channel_37',
#   'upslope_Channel_38',
#   'upslope_Channel_39',
#   'upslope_Channel_40',
#   'upslope_Channel_41',
#   'upslope_Channel_42',
#   'upslope_Channel_43',
#   'upslope_Channel_44',
#   'upslope_Channel_45',
#   'upslope_Channel_46',
#   'upslope_Channel_47',
#   'upslope_Channel_48',
#   'upslope_Channel_49',
#   'upslope_Channel_50',
#   'upslope_Channel_51',
#   'upslope_Channel_52',
#   'upslope_Channel_53',
#   'upslope_Channel_54',
#   'upslope_Channel_55',
#   'upslope_Channel_56',
#   'upslope_Channel_57',
#   'upslope_Channel_58',
#   'upslope_Channel_59',
#   'upslope_Channel_60',
#   'upslope_Channel_61',
#   'upslope_Channel_62',
#   'upslope_Channel_63',
#   'upslope_Channel_64',
#   'upslope_Channel_65',
#   'upslope_Channel_66',
#   'upslope_Channel_67',
#   'upslope_Channel_68',
#   'upslope_Channel_69',
#   'upslope_Channel_70',
#   'upslope_Channel_71',
#   'upslope_Channel_72',
#   'upslope_Channel_73',
#   'upslope_Channel_74',
#   'upslope_Channel_75',
#   'upslope_Channel_76',
#   'upslope_Channel_77',
#   'upslope_Channel_78',
#   'upslope_Channel_79',
#   'upslope_Channel_80',
#   'upslope_Channel_81',
#   'upslope_Channel_82',
#   'upslope_Channel_83',
#   'upslope_Channel_84',
#   'upslope_Channel_85',
#   'upslope_Channel_86',
#   'upslope_Channel_87',
#   'upslope_Channel_88',
#   'upslope_Channel_89',
#   'upslope_Channel_90',
#   'upslope_Channel_91',
#   'upslope_Channel_92',
#   'upslope_Channel_93',
#   'upslope_Channel_94',
#   'upslope_Channel_95',
#   'upslope_Channel_96',
#   'upslope_Channel_97',
#   'upslope_Channel_98',
#   'upslope_Channel_99',
#   'upslope_Channel_100',
#   'upslope_Channel_101',
#   'upslope_Channel_102',
#   'upslope_Channel_103',
#   'upslope_Channel_104',
#   'upslope_Channel_105',
#   'upslope_Channel_106',
#   'upslope_Channel_107',
#   'upslope_Channel_108',
#   'upslope_Channel_109',
#   'upslope_Channel_110',
#   'upslope_Channel_111',
#   'upslope_Channel_112',
#   'upslope_Channel_113',
#   'upslope_Channel_114',
#   'upslope_Channel_115',
#   'upslope_Channel_116',
#   'upslope_Channel_117',
#   'upslope_Channel_118',
#   'upslope_Channel_119',
#   'upslope_Channel_120',
#   'upslope_Channel_121',
#   'upslope_Channel_122',
#   'upslope_Channel_123',
#   'upslope_Channel_124',
#   'upslope_Channel_125',
#   'upslope_Channel_126',
#   'upslope_Channel_127',
#   'upslope_Channel_128',
#   'upslope_Channel_129',
#   'upslope_Channel_130',
#   'upslope_Channel_131',
#   'upslope_Channel_132',
#   'upslope_Channel_133',
#   'upslope_Channel_134',
#   'upslope_Channel_135',
#   'upslope_Channel_136',
#   'upslope_Channel_137',
#   'upslope_Channel_138',
#   'upslope_Channel_139',
#   'upslope_Channel_140',
#   'upslope_Channel_141',
#   'upslope_Channel_142',
#   'upslope_Channel_143',
#   'upslope_Channel_144',
#   'upslope_Channel_145',
#   'upslope_Channel_146',
#   'upslope_Channel_147',
#   'upslope_Channel_148',
#   'upslope_Channel_149',
#   'upslope_Channel_150',
#   'upslope_Channel_151',
#   'upslope_Channel_152',
#   'upslope_Channel_153',
#   'upslope_Channel_154',
#   'upslope_Channel_155',
#   'upslope_Channel_156',
#   'upslope_Channel_157',
#   'upslope_Channel_158',
#   'upslope_Channel_159',
#   'upslope_Channel_160',
#   'upslope_Channel_161',
#   'upslope_Channel_162',
#   'upslope_Channel_163',
#   'upslope_Channel_164',
#   'upslope_Channel_165',
#   'upslope_Channel_166',
#   'upslope_Channel_167',
#   'upslope_Channel_168',
#   'upslope_Channel_169',
#   'upslope_Channel_170',
#   'upslope_Channel_171',
#   'upslope_Channel_172',
#   'upslope_Channel_173',
#   'upslope_Channel_174',
#   'upslope_Channel_175',
#   'upslope_Channel_176',
#   'upslope_Channel_177',
#   'upslope_Channel_178',
#   'upslope_Channel_179',
#   'upslope_Channel_180',
#   'upslope_Channel_181',
#   'upslope_Channel_182',
#   'upslope_Channel_183',
#   'upslope_Channel_184',
#   'upslope_Channel_185',
#   'upslope_Channel_186',
#   'upslope_Channel_187',
#   'upslope_Channel_188',
#   'upslope_Channel_189',
#   'upslope_Channel_190',
#   'upslope_Channel_191',
#   'upslope_Channel_192',
#   'upslope_Channel_193',
#   'upslope_Channel_194',
#   'upslope_Channel_195',
#   'upslope_Channel_196',
#   'upslope_Channel_197',
#   'upslope_Channel_198',
#   'upslope_Channel_199',
#   'upslope_Channel_200',
#   'upslope_Channel_201',
#   'upslope_Channel_202',
#   'upslope_Channel_203',
#   'upslope_Channel_204',
#   'upslope_Channel_205',
#   'upslope_Channel_206',
#   'upslope_Channel_207',
#   'upslope_Channel_208',
#   'upslope_Channel_209',
#   'upslope_Channel_210',
#   'upslope_Channel_211',
#   'upslope_Channel_212',
#   'upslope_Channel_213',
#   'upslope_Channel_214',
#   'upslope_Channel_215',
#   'upslope_Channel_216',
#   'upslope_Channel_217',
#   'upslope_Channel_218',
#   'upslope_Channel_219',
#   'upslope_Channel_220',
#   'upslope_Channel_221',
#   'upslope_Channel_222',
#   'upslope_Channel_223',
#   'upslope_Channel_224',
#   'upslope_Channel_225',
#   'upslope_Channel_226',
#   'upslope_Channel_227',
#   'upslope_Channel_228',
#   'upslope_Channel_229',
#   'upslope_Channel_230',
#   'upslope_Channel_231',
#   'upslope_Channel_232',
#   'upslope_Channel_233',
#   'upslope_Channel_234',
#   'upslope_Channel_235',
#   'upslope_Channel_236',
#   'upslope_Channel_237',
#   'upslope_Channel_238',
#   'upslope_Channel_239',
#   'upslope_Channel_240',
#   'upslope_Channel_241',
#   'upslope_Channel_242',
#   'upslope_Channel_243',
#   'upslope_Channel_244',
#   'upslope_Channel_245',
#   'upslope_Channel_246',
#   'upslope_Channel_247',
#   'upslope_Channel_248',
#   'upslope_Channel_249',
#   'upslope_Channel_250',
#   'upslope_Channel_251',
#   'upslope_Channel_252',
#   'upslope_Channel_253',
#   'upslope_Channel_254',
#   'upslope_Channel_255',
#   'upslope_Channel_256',
#   'upslope_Channel_257',
#   'upslope_Channel_258',
#   'upslope_Channel_259',
#   'upslope_Channel_260',
#   'upslope_Channel_261',
#   'upslope_Channel_262',
#   'upslope_Channel_263',
#   'upslope_Channel_264',
#   'upslope_Channel_265',
#   'upslope_Channel_266',
#   'upslope_Channel_267',
#   'upslope_Channel_268',
#   'upslope_Channel_269',
#   'upslope_Channel_270',
#   'upslope_Channel_271',
#   'upslope_Channel_272',
#   'upslope_Channel_273',
#   'upslope_Channel_274'],
#  'downslope': ['downslope_Channel_1',
#   'downslope_Channel_2',
#   'downslope_Channel_3',
#   'downslope_Channel_4',
#   'downslope_Channel_5',
#   'downslope_Channel_6',
#   'downslope_Channel_7',
#   'downslope_Channel_8',
#   'downslope_Channel_9',
#   'downslope_Channel_10',
#   'downslope_Channel_11',
#   'downslope_Channel_12',
#   'downslope_Channel_13',
#   'downslope_Channel_14',
#   'downslope_Channel_15',
#   'downslope_Channel_16',
#   'downslope_Channel_17',
#   'downslope_Channel_18',
#   'downslope_Channel_19',
#   'downslope_Channel_20',
#   'downslope_Channel_21',
#   'downslope_Channel_22',
#   'downslope_Channel_23',
#   'downslope_Channel_24',
#   'downslope_Channel_25',
#   'downslope_Channel_26',
#   'downslope_Channel_27',
#   'downslope_Channel_28',
#   'downslope_Channel_29',
#   'downslope_Channel_30',
#   'downslope_Channel_31',
#   'downslope_Channel_32',
#   'downslope_Channel_33',
#   'downslope_Channel_34',
#   'downslope_Channel_35',
#   'downslope_Channel_36',
#   'downslope_Channel_37',
#   'downslope_Channel_38',
#   'downslope_Channel_39',
#   'downslope_Channel_40',
#   'downslope_Channel_41',
#   'downslope_Channel_42',
#   'downslope_Channel_43',
#   'downslope_Channel_44',
#   'downslope_Channel_45',
#   'downslope_Channel_46',
#   'downslope_Channel_47',
#   'downslope_Channel_48',
#   'downslope_Channel_49',
#   'downslope_Channel_50',
#   'downslope_Channel_51',
#   'downslope_Channel_52',
#   'downslope_Channel_53',
#   'downslope_Channel_54',
#   'downslope_Channel_55',
#   'downslope_Channel_56',
#   'downslope_Channel_57',
#   'downslope_Channel_58',
#   'downslope_Channel_59',
#   'downslope_Channel_60',
#   'downslope_Channel_61',
#   'downslope_Channel_62',
#   'downslope_Channel_63',
#   'downslope_Channel_64',
#   'downslope_Channel_65',
#   'downslope_Channel_66',
#   'downslope_Channel_67',
#   'downslope_Channel_68',
#   'downslope_Channel_69',
#   'downslope_Channel_70',
#   'downslope_Channel_71',
#   'downslope_Channel_72',
#   'downslope_Channel_73',
#   'downslope_Channel_74',
#   'downslope_Channel_75',
#   'downslope_Channel_76',
#   'downslope_Channel_77',
#   'downslope_Channel_78',
#   'downslope_Channel_79',
#   'downslope_Channel_80',
#   'downslope_Channel_81',
#   'downslope_Channel_82',
#   'downslope_Channel_83',
#   'downslope_Channel_84',
#   'downslope_Channel_85',
#   'downslope_Channel_86',
#   'downslope_Channel_87',
#   'downslope_Channel_88',
#   'downslope_Channel_89',
#   'downslope_Channel_90',
#   'downslope_Channel_91',
#   'downslope_Channel_92',
#   'downslope_Channel_93',
#   'downslope_Channel_94',
#   'downslope_Channel_95',
#   'downslope_Channel_96',
#   'downslope_Channel_97',
#   'downslope_Channel_98',
#   'downslope_Channel_99',
#   'downslope_Channel_100',
#   'downslope_Channel_101',
#   'downslope_Channel_102',
#   'downslope_Channel_103',
#   'downslope_Channel_104',
#   'downslope_Channel_105',
#   'downslope_Channel_106',
#   'downslope_Channel_107',
#   'downslope_Channel_108',
#   'downslope_Channel_109',
#   'downslope_Channel_110',
#   'downslope_Channel_111',
#   'downslope_Channel_112',
#   'downslope_Channel_113',
#   'downslope_Channel_114',
#   'downslope_Channel_115',
#   'downslope_Channel_116',
#   'downslope_Channel_117',
#   'downslope_Channel_118',
#   'downslope_Channel_119',
#   'downslope_Channel_120',
#   'downslope_Channel_121',
#   'downslope_Channel_122',
#   'downslope_Channel_123',
#   'downslope_Channel_124',
#   'downslope_Channel_125',
#   'downslope_Channel_126',
#   'downslope_Channel_127',
#   'downslope_Channel_128',
#   'downslope_Channel_129',
#   'downslope_Channel_130',
#   'downslope_Channel_131',
#   'downslope_Channel_132',
#   'downslope_Channel_133',
#   'downslope_Channel_134',
#   'downslope_Channel_135',
#   'downslope_Channel_136',
#   'downslope_Channel_137',
#   'downslope_Channel_138',
#   'downslope_Channel_139',
#   'downslope_Channel_140',
#   'downslope_Channel_141',
#   'downslope_Channel_142',
#   'downslope_Channel_143',
#   'downslope_Channel_144',
#   'downslope_Channel_145',
#   'downslope_Channel_146',
#   'downslope_Channel_147',
#   'downslope_Channel_148',
#   'downslope_Channel_149',
#   'downslope_Channel_150',
#   'downslope_Channel_151',
#   'downslope_Channel_152',
#   'downslope_Channel_153',
#   'downslope_Channel_154',
#   'downslope_Channel_155',
#   'downslope_Channel_156',
#   'downslope_Channel_157',
#   'downslope_Channel_158',
#   'downslope_Channel_159',
#   'downslope_Channel_160',
#   'downslope_Channel_161',
#   'downslope_Channel_162',
#   'downslope_Channel_163',
#   'downslope_Channel_164',
#   'downslope_Channel_165',
#   'downslope_Channel_166',
#   'downslope_Channel_167',
#   'downslope_Channel_168',
#   'downslope_Channel_169',
#   'downslope_Channel_170',
#   'downslope_Channel_171',
#   'downslope_Channel_172',
#   'downslope_Channel_173',
#   'downslope_Channel_174',
#   'downslope_Channel_175',
#   'downslope_Channel_176',
#   'downslope_Channel_177',
#   'downslope_Channel_178',
#   'downslope_Channel_179',
#   'downslope_Channel_180',
#   'downslope_Channel_181',
#   'downslope_Channel_182',
#   'downslope_Channel_183',
#   'downslope_Channel_184',
#   'downslope_Channel_185',
#   'downslope_Channel_186',
#   'downslope_Channel_187',
#   'downslope_Channel_188',
#   'downslope_Channel_189',
#   'downslope_Channel_190',
#   'downslope_Channel_191',
#   'downslope_Channel_192',
#   'downslope_Channel_193',
#   'downslope_Channel_194',
#   'downslope_Channel_195',
#   'downslope_Channel_196',
#   'downslope_Channel_197',
#   'downslope_Channel_198',
#   'downslope_Channel_199',
#   'downslope_Channel_200',
#   'downslope_Channel_201',
#   'downslope_Channel_202',
#   'downslope_Channel_203',
#   'downslope_Channel_204',
#   'downslope_Channel_205',
#   'downslope_Channel_206',
#   'downslope_Channel_207',
#   'downslope_Channel_208',
#   'downslope_Channel_209',
#   'downslope_Channel_210',
#   'downslope_Channel_211',
#   'downslope_Channel_212',
#   'downslope_Channel_213',
#   'downslope_Channel_214',
#   'downslope_Channel_215',
#   'downslope_Channel_216',
#   'downslope_Channel_217',
#   'downslope_Channel_218',
#   'downslope_Channel_219',
#   'downslope_Channel_220',
#   'downslope_Channel_221',
#   'downslope_Channel_222',
#   'downslope_Channel_223',
#   'downslope_Channel_224',
#   'downslope_Channel_225',
#   'downslope_Channel_226',
#   'downslope_Channel_227',
#   'downslope_Channel_228',
#   'downslope_Channel_229',
#   'downslope_Channel_230',
#   'downslope_Channel_231',
#   'downslope_Channel_232',
#   'downslope_Channel_233',
#   'downslope_Channel_234',
#   'downslope_Channel_235',
#   'downslope_Channel_236',
#   'downslope_Channel_237',
#   'downslope_Channel_238',
#   'downslope_Channel_239',
#   'downslope_Channel_240',
#   'downslope_Channel_241',
#   'downslope_Channel_242',
#   'downslope_Channel_243',
#   'downslope_Channel_244',
#   'downslope_Channel_245',
#   'downslope_Channel_246',
#   'downslope_Channel_247',
#   'downslope_Channel_248',
#   'downslope_Channel_249',
#   'downslope_Channel_250',
#   'downslope_Channel_251',
#   'downslope_Channel_252',
#   'downslope_Channel_253',
#   'downslope_Channel_254',
#   'downslope_Channel_255',
#   'downslope_Channel_256',
#   'downslope_Channel_257',
#   'downslope_Channel_258',
#   'downslope_Channel_259',
#   'downslope_Channel_260',
#   'downslope_Channel_261',
#   'downslope_Channel_262',
#   'downslope_Channel_263',
#   'downslope_Channel_264',
#   'downslope_Channel_265',
#   'downslope_Channel_266',
#   'downslope_Channel_267',
#   'downslope_Channel_268',
#   'downslope_Channel_269',
#   'downslope_Channel_270',
#   'downslope_Channel_271',
#   'downslope_Channel_272',
#   'downslope_Channel_273',
#   'downslope_Channel_274'],
#  'std': ['std_Channel_1',
#   'std_Channel_2',
#   'std_Channel_3',
#   'std_Channel_4',
#   'std_Channel_5',
#   'std_Channel_6',
#   'std_Channel_7',
#   'std_Channel_8',
#   'std_Channel_9',
#   'std_Channel_10',
#   'std_Channel_11',
#   'std_Channel_12',
#   'std_Channel_13',
#   'std_Channel_14',
#   'std_Channel_15',
#   'std_Channel_16',
#   'std_Channel_17',
#   'std_Channel_18',
#   'std_Channel_19',
#   'std_Channel_20',
#   'std_Channel_21',
#   'std_Channel_22',
#   'std_Channel_23',
#   'std_Channel_24',
#   'std_Channel_25',
#   'std_Channel_26',
#   'std_Channel_27',
#   'std_Channel_28',
#   'std_Channel_29',
#   'std_Channel_30',
#   'std_Channel_31',
#   'std_Channel_32',
#   'std_Channel_33',
#   'std_Channel_34',
#   'std_Channel_35',
#   'std_Channel_36',
#   'std_Channel_37',
#   'std_Channel_38',
#   'std_Channel_39',
#   'std_Channel_40',
#   'std_Channel_41',
#   'std_Channel_42',
#   'std_Channel_43',
#   'std_Channel_44',
#   'std_Channel_45',
#   'std_Channel_46',
#   'std_Channel_47',
#   'std_Channel_48',
#   'std_Channel_49',
#   'std_Channel_50',
#   'std_Channel_51',
#   'std_Channel_52',
#   'std_Channel_53',
#   'std_Channel_54',
#   'std_Channel_55',
#   'std_Channel_56',
#   'std_Channel_57',
#   'std_Channel_58',
#   'std_Channel_59',
#   'std_Channel_60',
#   'std_Channel_61',
#   'std_Channel_62',
#   'std_Channel_63',
#   'std_Channel_64',
#   'std_Channel_65',
#   'std_Channel_66',
#   'std_Channel_67',
#   'std_Channel_68',
#   'std_Channel_69',
#   'std_Channel_70',
#   'std_Channel_71',
#   'std_Channel_72',
#   'std_Channel_73',
#   'std_Channel_74',
#   'std_Channel_75',
#   'std_Channel_76',
#   'std_Channel_77',
#   'std_Channel_78',
#   'std_Channel_79',
#   'std_Channel_80',
#   'std_Channel_81',
#   'std_Channel_82',
#   'std_Channel_83',
#   'std_Channel_84',
#   'std_Channel_85',
#   'std_Channel_86',
#   'std_Channel_87',
#   'std_Channel_88',
#   'std_Channel_89',
#   'std_Channel_90',
#   'std_Channel_91',
#   'std_Channel_92',
#   'std_Channel_93',
#   'std_Channel_94',
#   'std_Channel_95',
#   'std_Channel_96',
#   'std_Channel_97',
#   'std_Channel_98',
#   'std_Channel_99',
#   'std_Channel_100',
#   'std_Channel_101',
#   'std_Channel_102',
#   'std_Channel_103',
#   'std_Channel_104',
#   'std_Channel_105',
#   'std_Channel_106',
#   'std_Channel_107',
#   'std_Channel_108',
#   'std_Channel_109',
#   'std_Channel_110',
#   'std_Channel_111',
#   'std_Channel_112',
#   'std_Channel_113',
#   'std_Channel_114',
#   'std_Channel_115',
#   'std_Channel_116',
#   'std_Channel_117',
#   'std_Channel_118',
#   'std_Channel_119',
#   'std_Channel_120',
#   'std_Channel_121',
#   'std_Channel_122',
#   'std_Channel_123',
#   'std_Channel_124',
#   'std_Channel_125',
#   'std_Channel_126',
#   'std_Channel_127',
#   'std_Channel_128',
#   'std_Channel_129',
#   'std_Channel_130',
#   'std_Channel_131',
#   'std_Channel_132',
#   'std_Channel_133',
#   'std_Channel_134',
#   'std_Channel_135',
#   'std_Channel_136',
#   'std_Channel_137',
#   'std_Channel_138',
#   'std_Channel_139',
#   'std_Channel_140',
#   'std_Channel_141',
#   'std_Channel_142',
#   'std_Channel_143',
#   'std_Channel_144',
#   'std_Channel_145',
#   'std_Channel_146',
#   'std_Channel_147',
#   'std_Channel_148',
#   'std_Channel_149',
#   'std_Channel_150',
#   'std_Channel_151',
#   'std_Channel_152',
#   'std_Channel_153',
#   'std_Channel_154',
#   'std_Channel_155',
#   'std_Channel_156',
#   'std_Channel_157',
#   'std_Channel_158',
#   'std_Channel_159',
#   'std_Channel_160',
#   'std_Channel_161',
#   'std_Channel_162',
#   'std_Channel_163',
#   'std_Channel_164',
#   'std_Channel_165',
#   'std_Channel_166',
#   'std_Channel_167',
#   'std_Channel_168',
#   'std_Channel_169',
#   'std_Channel_170',
#   'std_Channel_171',
#   'std_Channel_172',
#   'std_Channel_173',
#   'std_Channel_174',
#   'std_Channel_175',
#   'std_Channel_176',
#   'std_Channel_177',
#   'std_Channel_178',
#   'std_Channel_179',
#   'std_Channel_180',
#   'std_Channel_181',
#   'std_Channel_182',
#   'std_Channel_183',
#   'std_Channel_184',
#   'std_Channel_185',
#   'std_Channel_186',
#   'std_Channel_187',
#   'std_Channel_188',
#   'std_Channel_189',
#   'std_Channel_190',
#   'std_Channel_191',
#   'std_Channel_192',
#   'std_Channel_193',
#   'std_Channel_194',
#   'std_Channel_195',
#   'std_Channel_196',
#   'std_Channel_197',
#   'std_Channel_198',
#   'std_Channel_199',
#   'std_Channel_200',
#   'std_Channel_201',
#   'std_Channel_202',
#   'std_Channel_203',
#   'std_Channel_204',
#   'std_Channel_205',
#   'std_Channel_206',
#   'std_Channel_207',
#   'std_Channel_208',
#   'std_Channel_209',
#   'std_Channel_210',
#   'std_Channel_211',
#   'std_Channel_212',
#   'std_Channel_213',
#   'std_Channel_214',
#   'std_Channel_215',
#   'std_Channel_216',
#   'std_Channel_217',
#   'std_Channel_218',
#   'std_Channel_219',
#   'std_Channel_220',
#   'std_Channel_221',
#   'std_Channel_222',
#   'std_Channel_223',
#   'std_Channel_224',
#   'std_Channel_225',
#   'std_Channel_226',
#   'std_Channel_227',
#   'std_Channel_228',
#   'std_Channel_229',
#   'std_Channel_230',
#   'std_Channel_231',
#   'std_Channel_232',
#   'std_Channel_233',
#   'std_Channel_234',
#   'std_Channel_235',
#   'std_Channel_236',
#   'std_Channel_237',
#   'std_Channel_238',
#   'std_Channel_239',
#   'std_Channel_240',
#   'std_Channel_241',
#   'std_Channel_242',
#   'std_Channel_243',
#   'std_Channel_244',
#   'std_Channel_245',
#   'std_Channel_246',
#   'std_Channel_247',
#   'std_Channel_248',
#   'std_Channel_249',
#   'std_Channel_250',
#   'std_Channel_251',
#   'std_Channel_252',
#   'std_Channel_253',
#   'std_Channel_254',
#   'std_Channel_255',
#   'std_Channel_256',
#   'std_Channel_257',
#   'std_Channel_258',
#   'std_Channel_259',
#   'std_Channel_260',
#   'std_Channel_261',
#   'std_Channel_262',
#   'std_Channel_263',
#   'std_Channel_264',
#   'std_Channel_265',
#   'std_Channel_266',
#   'std_Channel_267',
#   'std_Channel_268',
#   'std_Channel_269',
#   'std_Channel_270',
#   'std_Channel_271',
#   'std_Channel_272',
#   'std_Channel_273',
#   'std_Channel_274'],
#  'amplitude_ratio': ['amplitude_ratio_Channel_1',
#   'amplitude_ratio_Channel_2',
#   'amplitude_ratio_Channel_3',
#   'amplitude_ratio_Channel_4',
#   'amplitude_ratio_Channel_5',
#   'amplitude_ratio_Channel_6',
#   'amplitude_ratio_Channel_7',
#   'amplitude_ratio_Channel_8',
#   'amplitude_ratio_Channel_9',
#   'amplitude_ratio_Channel_10',
#   'amplitude_ratio_Channel_11',
#   'amplitude_ratio_Channel_12',
#   'amplitude_ratio_Channel_13',
#   'amplitude_ratio_Channel_14',
#   'amplitude_ratio_Channel_15',
#   'amplitude_ratio_Channel_16',
#   'amplitude_ratio_Channel_17',
#   'amplitude_ratio_Channel_18',
#   'amplitude_ratio_Channel_19',
#   'amplitude_ratio_Channel_20',
#   'amplitude_ratio_Channel_21',
#   'amplitude_ratio_Channel_22',
#   'amplitude_ratio_Channel_23',
#   'amplitude_ratio_Channel_24',
#   'amplitude_ratio_Channel_25',
#   'amplitude_ratio_Channel_26',
#   'amplitude_ratio_Channel_27',
#   'amplitude_ratio_Channel_28',
#   'amplitude_ratio_Channel_29',
#   'amplitude_ratio_Channel_30',
#   'amplitude_ratio_Channel_31',
#   'amplitude_ratio_Channel_32',
#   'amplitude_ratio_Channel_33',
#   'amplitude_ratio_Channel_34',
#   'amplitude_ratio_Channel_35',
#   'amplitude_ratio_Channel_36',
#   'amplitude_ratio_Channel_37',
#   'amplitude_ratio_Channel_38',
#   'amplitude_ratio_Channel_39',
#   'amplitude_ratio_Channel_40',
#   'amplitude_ratio_Channel_41',
#   'amplitude_ratio_Channel_42',
#   'amplitude_ratio_Channel_43',
#   'amplitude_ratio_Channel_44',
#   'amplitude_ratio_Channel_45',
#   'amplitude_ratio_Channel_46',
#   'amplitude_ratio_Channel_47',
#   'amplitude_ratio_Channel_48',
#   'amplitude_ratio_Channel_49',
#   'amplitude_ratio_Channel_50',
#   'amplitude_ratio_Channel_51',
#   'amplitude_ratio_Channel_52',
#   'amplitude_ratio_Channel_53',
#   'amplitude_ratio_Channel_54',
#   'amplitude_ratio_Channel_55',
#   'amplitude_ratio_Channel_56',
#   'amplitude_ratio_Channel_57',
#   'amplitude_ratio_Channel_58',
#   'amplitude_ratio_Channel_59',
#   'amplitude_ratio_Channel_60',
#   'amplitude_ratio_Channel_61',
#   'amplitude_ratio_Channel_62',
#   'amplitude_ratio_Channel_63',
#   'amplitude_ratio_Channel_64',
#   'amplitude_ratio_Channel_65',
#   'amplitude_ratio_Channel_66',
#   'amplitude_ratio_Channel_67',
#   'amplitude_ratio_Channel_68',
#   'amplitude_ratio_Channel_69',
#   'amplitude_ratio_Channel_70',
#   'amplitude_ratio_Channel_71',
#   'amplitude_ratio_Channel_72',
#   'amplitude_ratio_Channel_73',
#   'amplitude_ratio_Channel_74',
#   'amplitude_ratio_Channel_75',
#   'amplitude_ratio_Channel_76',
#   'amplitude_ratio_Channel_77',
#   'amplitude_ratio_Channel_78',
#   'amplitude_ratio_Channel_79',
#   'amplitude_ratio_Channel_80',
#   'amplitude_ratio_Channel_81',
#   'amplitude_ratio_Channel_82',
#   'amplitude_ratio_Channel_83',
#   'amplitude_ratio_Channel_84',
#   'amplitude_ratio_Channel_85',
#   'amplitude_ratio_Channel_86',
#   'amplitude_ratio_Channel_87',
#   'amplitude_ratio_Channel_88',
#   'amplitude_ratio_Channel_89',
#   'amplitude_ratio_Channel_90',
#   'amplitude_ratio_Channel_91',
#   'amplitude_ratio_Channel_92',
#   'amplitude_ratio_Channel_93',
#   'amplitude_ratio_Channel_94',
#   'amplitude_ratio_Channel_95',
#   'amplitude_ratio_Channel_96',
#   'amplitude_ratio_Channel_97',
#   'amplitude_ratio_Channel_98',
#   'amplitude_ratio_Channel_99',
#   'amplitude_ratio_Channel_100',
#   'amplitude_ratio_Channel_101',
#   'amplitude_ratio_Channel_102',
#   'amplitude_ratio_Channel_103',
#   'amplitude_ratio_Channel_104',
#   'amplitude_ratio_Channel_105',
#   'amplitude_ratio_Channel_106',
#   'amplitude_ratio_Channel_107',
#   'amplitude_ratio_Channel_108',
#   'amplitude_ratio_Channel_109',
#   'amplitude_ratio_Channel_110',
#   'amplitude_ratio_Channel_111',
#   'amplitude_ratio_Channel_112',
#   'amplitude_ratio_Channel_113',
#   'amplitude_ratio_Channel_114',
#   'amplitude_ratio_Channel_115',
#   'amplitude_ratio_Channel_116',
#   'amplitude_ratio_Channel_117',
#   'amplitude_ratio_Channel_118',
#   'amplitude_ratio_Channel_119',
#   'amplitude_ratio_Channel_120',
#   'amplitude_ratio_Channel_121',
#   'amplitude_ratio_Channel_122',
#   'amplitude_ratio_Channel_123',
#   'amplitude_ratio_Channel_124',
#   'amplitude_ratio_Channel_125',
#   'amplitude_ratio_Channel_126',
#   'amplitude_ratio_Channel_127',
#   'amplitude_ratio_Channel_128',
#   'amplitude_ratio_Channel_129',
#   'amplitude_ratio_Channel_130',
#   'amplitude_ratio_Channel_131',
#   'amplitude_ratio_Channel_132',
#   'amplitude_ratio_Channel_133',
#   'amplitude_ratio_Channel_134',
#   'amplitude_ratio_Channel_135',
#   'amplitude_ratio_Channel_136',
#   'amplitude_ratio_Channel_137',
#   'amplitude_ratio_Channel_138',
#   'amplitude_ratio_Channel_139',
#   'amplitude_ratio_Channel_140',
#   'amplitude_ratio_Channel_141',
#   'amplitude_ratio_Channel_142',
#   'amplitude_ratio_Channel_143',
#   'amplitude_ratio_Channel_144',
#   'amplitude_ratio_Channel_145',
#   'amplitude_ratio_Channel_146',
#   'amplitude_ratio_Channel_147',
#   'amplitude_ratio_Channel_148',
#   'amplitude_ratio_Channel_149',
#   'amplitude_ratio_Channel_150',
#   'amplitude_ratio_Channel_151',
#   'amplitude_ratio_Channel_152',
#   'amplitude_ratio_Channel_153',
#   'amplitude_ratio_Channel_154',
#   'amplitude_ratio_Channel_155',
#   'amplitude_ratio_Channel_156',
#   'amplitude_ratio_Channel_157',
#   'amplitude_ratio_Channel_158',
#   'amplitude_ratio_Channel_159',
#   'amplitude_ratio_Channel_160',
#   'amplitude_ratio_Channel_161',
#   'amplitude_ratio_Channel_162',
#   'amplitude_ratio_Channel_163',
#   'amplitude_ratio_Channel_164',
#   'amplitude_ratio_Channel_165',
#   'amplitude_ratio_Channel_166',
#   'amplitude_ratio_Channel_167',
#   'amplitude_ratio_Channel_168',
#   'amplitude_ratio_Channel_169',
#   'amplitude_ratio_Channel_170',
#   'amplitude_ratio_Channel_171',
#   'amplitude_ratio_Channel_172',
#   'amplitude_ratio_Channel_173',
#   'amplitude_ratio_Channel_174',
#   'amplitude_ratio_Channel_175',
#   'amplitude_ratio_Channel_176',
#   'amplitude_ratio_Channel_177',
#   'amplitude_ratio_Channel_178',
#   'amplitude_ratio_Channel_179',
#   'amplitude_ratio_Channel_180',
#   'amplitude_ratio_Channel_181',
#   'amplitude_ratio_Channel_182',
#   'amplitude_ratio_Channel_183',
#   'amplitude_ratio_Channel_184',
#   'amplitude_ratio_Channel_185',
#   'amplitude_ratio_Channel_186',
#   'amplitude_ratio_Channel_187',
#   'amplitude_ratio_Channel_188',
#   'amplitude_ratio_Channel_189',
#   'amplitude_ratio_Channel_190',
#   'amplitude_ratio_Channel_191',
#   'amplitude_ratio_Channel_192',
#   'amplitude_ratio_Channel_193',
#   'amplitude_ratio_Channel_194',
#   'amplitude_ratio_Channel_195',
#   'amplitude_ratio_Channel_196',
#   'amplitude_ratio_Channel_197',
#   'amplitude_ratio_Channel_198',
#   'amplitude_ratio_Channel_199',
#   'amplitude_ratio_Channel_200',
#   'amplitude_ratio_Channel_201',
#   'amplitude_ratio_Channel_202',
#   'amplitude_ratio_Channel_203',
#   'amplitude_ratio_Channel_204',
#   'amplitude_ratio_Channel_205',
#   'amplitude_ratio_Channel_206',
#   'amplitude_ratio_Channel_207',
#   'amplitude_ratio_Channel_208',
#   'amplitude_ratio_Channel_209',
#   'amplitude_ratio_Channel_210',
#   'amplitude_ratio_Channel_211',
#   'amplitude_ratio_Channel_212',
#   'amplitude_ratio_Channel_213',
#   'amplitude_ratio_Channel_214',
#   'amplitude_ratio_Channel_215',
#   'amplitude_ratio_Channel_216',
#   'amplitude_ratio_Channel_217',
#   'amplitude_ratio_Channel_218',
#   'amplitude_ratio_Channel_219',
#   'amplitude_ratio_Channel_220',
#   'amplitude_ratio_Channel_221',
#   'amplitude_ratio_Channel_222',
#   'amplitude_ratio_Channel_223',
#   'amplitude_ratio_Channel_224',
#   'amplitude_ratio_Channel_225',
#   'amplitude_ratio_Channel_226',
#   'amplitude_ratio_Channel_227',
#   'amplitude_ratio_Channel_228',
#   'amplitude_ratio_Channel_229',
#   'amplitude_ratio_Channel_230',
#   'amplitude_ratio_Channel_231',
#   'amplitude_ratio_Channel_232',
#   'amplitude_ratio_Channel_233',
#   'amplitude_ratio_Channel_234',
#   'amplitude_ratio_Channel_235',
#   'amplitude_ratio_Channel_236',
#   'amplitude_ratio_Channel_237',
#   'amplitude_ratio_Channel_238',
#   'amplitude_ratio_Channel_239',
#   'amplitude_ratio_Channel_240',
#   'amplitude_ratio_Channel_241',
#   'amplitude_ratio_Channel_242',
#   'amplitude_ratio_Channel_243',
#   'amplitude_ratio_Channel_244',
#   'amplitude_ratio_Channel_245',
#   'amplitude_ratio_Channel_246',
#   'amplitude_ratio_Channel_247',
#   'amplitude_ratio_Channel_248',
#   'amplitude_ratio_Channel_249',
#   'amplitude_ratio_Channel_250',
#   'amplitude_ratio_Channel_251',
#   'amplitude_ratio_Channel_252',
#   'amplitude_ratio_Channel_253',
#   'amplitude_ratio_Channel_254',
#   'amplitude_ratio_Channel_255',
#   'amplitude_ratio_Channel_256',
#   'amplitude_ratio_Channel_257',
#   'amplitude_ratio_Channel_258',
#   'amplitude_ratio_Channel_259',
#   'amplitude_ratio_Channel_260',
#   'amplitude_ratio_Channel_261',
#   'amplitude_ratio_Channel_262',
#   'amplitude_ratio_Channel_263',
#   'amplitude_ratio_Channel_264',
#   'amplitude_ratio_Channel_265',
#   'amplitude_ratio_Channel_266',
#   'amplitude_ratio_Channel_267',
#   'amplitude_ratio_Channel_268',
#   'amplitude_ratio_Channel_269',
#   'amplitude_ratio_Channel_270',
#   'amplitude_ratio_Channel_271',
#   'amplitude_ratio_Channel_272',
#   'amplitude_ratio_Channel_273',
#   'amplitude_ratio_Channel_274'],
#  'sharpness': ['sharpness_Channel_1',
#   'sharpness_Channel_2',
#   'sharpness_Channel_3',
#   'sharpness_Channel_4',
#   'sharpness_Channel_5',
#   'sharpness_Channel_6',
#   'sharpness_Channel_7',
#   'sharpness_Channel_8',
#   'sharpness_Channel_9',
#   'sharpness_Channel_10',
#   'sharpness_Channel_11',
#   'sharpness_Channel_12',
#   'sharpness_Channel_13',
#   'sharpness_Channel_14',
#   'sharpness_Channel_15',
#   'sharpness_Channel_16',
#   'sharpness_Channel_17',
#   'sharpness_Channel_18',
#   'sharpness_Channel_19',
#   'sharpness_Channel_20',
#   'sharpness_Channel_21',
#   'sharpness_Channel_22',
#   'sharpness_Channel_23',
#   'sharpness_Channel_24',
#   'sharpness_Channel_25',
#   'sharpness_Channel_26',
#   'sharpness_Channel_27',
#   'sharpness_Channel_28',
#   'sharpness_Channel_29',
#   'sharpness_Channel_30',
#   'sharpness_Channel_31',
#   'sharpness_Channel_32',
#   'sharpness_Channel_33',
#   'sharpness_Channel_34',
#   'sharpness_Channel_35',
#   'sharpness_Channel_36',
#   'sharpness_Channel_37',
#   'sharpness_Channel_38',
#   'sharpness_Channel_39',
#   'sharpness_Channel_40',
#   'sharpness_Channel_41',
#   'sharpness_Channel_42',
#   'sharpness_Channel_43',
#   'sharpness_Channel_44',
#   'sharpness_Channel_45',
#   'sharpness_Channel_46',
#   'sharpness_Channel_47',
#   'sharpness_Channel_48',
#   'sharpness_Channel_49',
#   'sharpness_Channel_50',
#   'sharpness_Channel_51',
#   'sharpness_Channel_52',
#   'sharpness_Channel_53',
#   'sharpness_Channel_54',
#   'sharpness_Channel_55',
#   'sharpness_Channel_56',
#   'sharpness_Channel_57',
#   'sharpness_Channel_58',
#   'sharpness_Channel_59',
#   'sharpness_Channel_60',
#   'sharpness_Channel_61',
#   'sharpness_Channel_62',
#   'sharpness_Channel_63',
#   'sharpness_Channel_64',
#   'sharpness_Channel_65',
#   'sharpness_Channel_66',
#   'sharpness_Channel_67',
#   'sharpness_Channel_68',
#   'sharpness_Channel_69',
#   'sharpness_Channel_70',
#   'sharpness_Channel_71',
#   'sharpness_Channel_72',
#   'sharpness_Channel_73',
#   'sharpness_Channel_74',
#   'sharpness_Channel_75',
#   'sharpness_Channel_76',
#   'sharpness_Channel_77',
#   'sharpness_Channel_78',
#   'sharpness_Channel_79',
#   'sharpness_Channel_80',
#   'sharpness_Channel_81',
#   'sharpness_Channel_82',
#   'sharpness_Channel_83',
#   'sharpness_Channel_84',
#   'sharpness_Channel_85',
#   'sharpness_Channel_86',
#   'sharpness_Channel_87',
#   'sharpness_Channel_88',
#   'sharpness_Channel_89',
#   'sharpness_Channel_90',
#   'sharpness_Channel_91',
#   'sharpness_Channel_92',
#   'sharpness_Channel_93',
#   'sharpness_Channel_94',
#   'sharpness_Channel_95',
#   'sharpness_Channel_96',
#   'sharpness_Channel_97',
#   'sharpness_Channel_98',
#   'sharpness_Channel_99',
#   'sharpness_Channel_100',
#   'sharpness_Channel_101',
#   'sharpness_Channel_102',
#   'sharpness_Channel_103',
#   'sharpness_Channel_104',
#   'sharpness_Channel_105',
#   'sharpness_Channel_106',
#   'sharpness_Channel_107',
#   'sharpness_Channel_108',
#   'sharpness_Channel_109',
#   'sharpness_Channel_110',
#   'sharpness_Channel_111',
#   'sharpness_Channel_112',
#   'sharpness_Channel_113',
#   'sharpness_Channel_114',
#   'sharpness_Channel_115',
#   'sharpness_Channel_116',
#   'sharpness_Channel_117',
#   'sharpness_Channel_118',
#   'sharpness_Channel_119',
#   'sharpness_Channel_120',
#   'sharpness_Channel_121',
#   'sharpness_Channel_122',
#   'sharpness_Channel_123',
#   'sharpness_Channel_124',
#   'sharpness_Channel_125',
#   'sharpness_Channel_126',
#   'sharpness_Channel_127',
#   'sharpness_Channel_128',
#   'sharpness_Channel_129',
#   'sharpness_Channel_130',
#   'sharpness_Channel_131',
#   'sharpness_Channel_132',
#   'sharpness_Channel_133',
#   'sharpness_Channel_134',
#   'sharpness_Channel_135',
#   'sharpness_Channel_136',
#   'sharpness_Channel_137',
#   'sharpness_Channel_138',
#   'sharpness_Channel_139',
#   'sharpness_Channel_140',
#   'sharpness_Channel_141',
#   'sharpness_Channel_142',
#   'sharpness_Channel_143',
#   'sharpness_Channel_144',
#   'sharpness_Channel_145',
#   'sharpness_Channel_146',
#   'sharpness_Channel_147',
#   'sharpness_Channel_148',
#   'sharpness_Channel_149',
#   'sharpness_Channel_150',
#   'sharpness_Channel_151',
#   'sharpness_Channel_152',
#   'sharpness_Channel_153',
#   'sharpness_Channel_154',
#   'sharpness_Channel_155',
#   'sharpness_Channel_156',
#   'sharpness_Channel_157',
#   'sharpness_Channel_158',
#   'sharpness_Channel_159',
#   'sharpness_Channel_160',
#   'sharpness_Channel_161',
#   'sharpness_Channel_162',
#   'sharpness_Channel_163',
#   'sharpness_Channel_164',
#   'sharpness_Channel_165',
#   'sharpness_Channel_166',
#   'sharpness_Channel_167',
#   'sharpness_Channel_168',
#   'sharpness_Channel_169',
#   'sharpness_Channel_170',
#   'sharpness_Channel_171',
#   'sharpness_Channel_172',
#   'sharpness_Channel_173',
#   'sharpness_Channel_174',
#   'sharpness_Channel_175',
#   'sharpness_Channel_176',
#   'sharpness_Channel_177',
#   'sharpness_Channel_178',
#   'sharpness_Channel_179',
#   'sharpness_Channel_180',
#   'sharpness_Channel_181',
#   'sharpness_Channel_182',
#   'sharpness_Channel_183',
#   'sharpness_Channel_184',
#   'sharpness_Channel_185',
#   'sharpness_Channel_186',
#   'sharpness_Channel_187',
#   'sharpness_Channel_188',
#   'sharpness_Channel_189',
#   'sharpness_Channel_190',
#   'sharpness_Channel_191',
#   'sharpness_Channel_192',
#   'sharpness_Channel_193',
#   'sharpness_Channel_194',
#   'sharpness_Channel_195',
#   'sharpness_Channel_196',
#   'sharpness_Channel_197',
#   'sharpness_Channel_198',
#   'sharpness_Channel_199',
#   'sharpness_Channel_200',
#   'sharpness_Channel_201',
#   'sharpness_Channel_202',
#   'sharpness_Channel_203',
#   'sharpness_Channel_204',
#   'sharpness_Channel_205',
#   'sharpness_Channel_206',
#   'sharpness_Channel_207',
#   'sharpness_Channel_208',
#   'sharpness_Channel_209',
#   'sharpness_Channel_210',
#   'sharpness_Channel_211',
#   'sharpness_Channel_212',
#   'sharpness_Channel_213',
#   'sharpness_Channel_214',
#   'sharpness_Channel_215',
#   'sharpness_Channel_216',
#   'sharpness_Channel_217',
#   'sharpness_Channel_218',
#   'sharpness_Channel_219',
#   'sharpness_Channel_220',
#   'sharpness_Channel_221',
#   'sharpness_Channel_222',
#   'sharpness_Channel_223',
#   'sharpness_Channel_224',
#   'sharpness_Channel_225',
#   'sharpness_Channel_226',
#   'sharpness_Channel_227',
#   'sharpness_Channel_228',
#   'sharpness_Channel_229',
#   'sharpness_Channel_230',
#   'sharpness_Channel_231',
#   'sharpness_Channel_232',
#   'sharpness_Channel_233',
#   'sharpness_Channel_234',
#   'sharpness_Channel_235',
#   'sharpness_Channel_236',
#   'sharpness_Channel_237',
#   'sharpness_Channel_238',
#   'sharpness_Channel_239',
#   'sharpness_Channel_240',
#   'sharpness_Channel_241',
#   'sharpness_Channel_242',
#   'sharpness_Channel_243',
#   'sharpness_Channel_244',
#   'sharpness_Channel_245',
#   'sharpness_Channel_246',
#   'sharpness_Channel_247',
#   'sharpness_Channel_248',
#   'sharpness_Channel_249',
#   'sharpness_Channel_250',
#   'sharpness_Channel_251',
#   'sharpness_Channel_252',
#   'sharpness_Channel_253',
#   'sharpness_Channel_254',
#   'sharpness_Channel_255',
#   'sharpness_Channel_256',
#   'sharpness_Channel_257',
#   'sharpness_Channel_258',
#   'sharpness_Channel_259',
#   'sharpness_Channel_260',
#   'sharpness_Channel_261',
#   'sharpness_Channel_262',
#   'sharpness_Channel_263',
#   'sharpness_Channel_264',
#   'sharpness_Channel_265',
#   'sharpness_Channel_266',
#   'sharpness_Channel_267',
#   'sharpness_Channel_268',
#   'sharpness_Channel_269',
#   'sharpness_Channel_270',
#   'sharpness_Channel_271',
#   'sharpness_Channel_272',
#   'sharpness_Channel_273',
#   'sharpness_Channel_274'],
#  'average_slope': ['average_slope_Channel_1',
#   'average_slope_Channel_2',
#   'average_slope_Channel_3',
#   'average_slope_Channel_4',
#   'average_slope_Channel_5',
#   'average_slope_Channel_6',
#   'average_slope_Channel_7',
#   'average_slope_Channel_8',
#   'average_slope_Channel_9',
#   'average_slope_Channel_10',
#   'average_slope_Channel_11',
#   'average_slope_Channel_12',
#   'average_slope_Channel_13',
#   'average_slope_Channel_14',
#   'average_slope_Channel_15',
#   'average_slope_Channel_16',
#   'average_slope_Channel_17',
#   'average_slope_Channel_18',
#   'average_slope_Channel_19',
#   'average_slope_Channel_20',
#   'average_slope_Channel_21',
#   'average_slope_Channel_22',
#   'average_slope_Channel_23',
#   'average_slope_Channel_24',
#   'average_slope_Channel_25',
#   'average_slope_Channel_26',
#   'average_slope_Channel_27',
#   'average_slope_Channel_28',
#   'average_slope_Channel_29',
#   'average_slope_Channel_30',
#   'average_slope_Channel_31',
#   'average_slope_Channel_32',
#   'average_slope_Channel_33',
#   'average_slope_Channel_34',
#   'average_slope_Channel_35',
#   'average_slope_Channel_36',
#   'average_slope_Channel_37',
#   'average_slope_Channel_38',
#   'average_slope_Channel_39',
#   'average_slope_Channel_40',
#   'average_slope_Channel_41',
#   'average_slope_Channel_42',
#   'average_slope_Channel_43',
#   'average_slope_Channel_44',
#   'average_slope_Channel_45',
#   'average_slope_Channel_46',
#   'average_slope_Channel_47',
#   'average_slope_Channel_48',
#   'average_slope_Channel_49',
#   'average_slope_Channel_50',
#   'average_slope_Channel_51',
#   'average_slope_Channel_52',
#   'average_slope_Channel_53',
#   'average_slope_Channel_54',
#   'average_slope_Channel_55',
#   'average_slope_Channel_56',
#   'average_slope_Channel_57',
#   'average_slope_Channel_58',
#   'average_slope_Channel_59',
#   'average_slope_Channel_60',
#   'average_slope_Channel_61',
#   'average_slope_Channel_62',
#   'average_slope_Channel_63',
#   'average_slope_Channel_64',
#   'average_slope_Channel_65',
#   'average_slope_Channel_66',
#   'average_slope_Channel_67',
#   'average_slope_Channel_68',
#   'average_slope_Channel_69',
#   'average_slope_Channel_70',
#   'average_slope_Channel_71',
#   'average_slope_Channel_72',
#   'average_slope_Channel_73',
#   'average_slope_Channel_74',
#   'average_slope_Channel_75',
#   'average_slope_Channel_76',
#   'average_slope_Channel_77',
#   'average_slope_Channel_78',
#   'average_slope_Channel_79',
#   'average_slope_Channel_80',
#   'average_slope_Channel_81',
#   'average_slope_Channel_82',
#   'average_slope_Channel_83',
#   'average_slope_Channel_84',
#   'average_slope_Channel_85',
#   'average_slope_Channel_86',
#   'average_slope_Channel_87',
#   'average_slope_Channel_88',
#   'average_slope_Channel_89',
#   'average_slope_Channel_90',
#   'average_slope_Channel_91',
#   'average_slope_Channel_92',
#   'average_slope_Channel_93',
#   'average_slope_Channel_94',
#   'average_slope_Channel_95',
#   'average_slope_Channel_96',
#   'average_slope_Channel_97',
#   'average_slope_Channel_98',
#   'average_slope_Channel_99',
#   'average_slope_Channel_100',
#   'average_slope_Channel_101',
#   'average_slope_Channel_102',
#   'average_slope_Channel_103',
#   'average_slope_Channel_104',
#   'average_slope_Channel_105',
#   'average_slope_Channel_106',
#   'average_slope_Channel_107',
#   'average_slope_Channel_108',
#   'average_slope_Channel_109',
#   'average_slope_Channel_110',
#   'average_slope_Channel_111',
#   'average_slope_Channel_112',
#   'average_slope_Channel_113',
#   'average_slope_Channel_114',
#   'average_slope_Channel_115',
#   'average_slope_Channel_116',
#   'average_slope_Channel_117',
#   'average_slope_Channel_118',
#   'average_slope_Channel_119',
#   'average_slope_Channel_120',
#   'average_slope_Channel_121',
#   'average_slope_Channel_122',
#   'average_slope_Channel_123',
#   'average_slope_Channel_124',
#   'average_slope_Channel_125',
#   'average_slope_Channel_126',
#   'average_slope_Channel_127',
#   'average_slope_Channel_128',
#   'average_slope_Channel_129',
#   'average_slope_Channel_130',
#   'average_slope_Channel_131',
#   'average_slope_Channel_132',
#   'average_slope_Channel_133',
#   'average_slope_Channel_134',
#   'average_slope_Channel_135',
#   'average_slope_Channel_136',
#   'average_slope_Channel_137',
#   'average_slope_Channel_138',
#   'average_slope_Channel_139',
#   'average_slope_Channel_140',
#   'average_slope_Channel_141',
#   'average_slope_Channel_142',
#   'average_slope_Channel_143',
#   'average_slope_Channel_144',
#   'average_slope_Channel_145',
#   'average_slope_Channel_146',
#   'average_slope_Channel_147',
#   'average_slope_Channel_148',
#   'average_slope_Channel_149',
#   'average_slope_Channel_150',
#   'average_slope_Channel_151',
#   'average_slope_Channel_152',
#   'average_slope_Channel_153',
#   'average_slope_Channel_154',
#   'average_slope_Channel_155',
#   'average_slope_Channel_156',
#   'average_slope_Channel_157',
#   'average_slope_Channel_158',
#   'average_slope_Channel_159',
#   'average_slope_Channel_160',
#   'average_slope_Channel_161',
#   'average_slope_Channel_162',
#   'average_slope_Channel_163',
#   'average_slope_Channel_164',
#   'average_slope_Channel_165',
#   'average_slope_Channel_166',
#   'average_slope_Channel_167',
#   'average_slope_Channel_168',
#   'average_slope_Channel_169',
#   'average_slope_Channel_170',
#   'average_slope_Channel_171',
#   'average_slope_Channel_172',
#   'average_slope_Channel_173',
#   'average_slope_Channel_174',
#   'average_slope_Channel_175',
#   'average_slope_Channel_176',
#   'average_slope_Channel_177',
#   'average_slope_Channel_178',
#   'average_slope_Channel_179',
#   'average_slope_Channel_180',
#   'average_slope_Channel_181',
#   'average_slope_Channel_182',
#   'average_slope_Channel_183',
#   'average_slope_Channel_184',
#   'average_slope_Channel_185',
#   'average_slope_Channel_186',
#   'average_slope_Channel_187',
#   'average_slope_Channel_188',
#   'average_slope_Channel_189',
#   'average_slope_Channel_190',
#   'average_slope_Channel_191',
#   'average_slope_Channel_192',
#   'average_slope_Channel_193',
#   'average_slope_Channel_194',
#   'average_slope_Channel_195',
#   'average_slope_Channel_196',
#   'average_slope_Channel_197',
#   'average_slope_Channel_198',
#   'average_slope_Channel_199',
#   'average_slope_Channel_200',
#   'average_slope_Channel_201',
#   'average_slope_Channel_202',
#   'average_slope_Channel_203',
#   'average_slope_Channel_204',
#   'average_slope_Channel_205',
#   'average_slope_Channel_206',
#   'average_slope_Channel_207',
#   'average_slope_Channel_208',
# ...
#   'main_frequency_Channel_63',
#   'main_frequency_Channel_64',
#   'main_frequency_Channel_65',
#   'main_frequency_Channel_66',
#   'main_frequency_Channel_67',
#   'main_frequency_Channel_68',
#   'main_frequency_Channel_69',
#   'main_frequency_Channel_70',
#   'main_frequency_Channel_71',
#   'main_frequency_Channel_72',
#   'main_frequency_Channel_73',
#   'main_frequency_Channel_74',
#   'main_frequency_Channel_75',
#   'main_frequency_Channel_76',
#   'main_frequency_Channel_77',
#   'main_frequency_Channel_78',
#   'main_frequency_Channel_79',
#   'main_frequency_Channel_80',
#   'main_frequency_Channel_81',
#   'main_frequency_Channel_82',
#   'main_frequency_Channel_83',
#   'main_frequency_Channel_84',
#   'main_frequency_Channel_85',
#   'main_frequency_Channel_86',
#   'main_frequency_Channel_87',
#   'main_frequency_Channel_88',
#   'main_frequency_Channel_89',
#   'main_frequency_Channel_90',
#   'main_frequency_Channel_91',
#   'main_frequency_Channel_92',
#   'main_frequency_Channel_93',
#   'main_frequency_Channel_94',
#   'main_frequency_Channel_95',
#   'main_frequency_Channel_96',
#   'main_frequency_Channel_97',
#   'main_frequency_Channel_98',
#   'main_frequency_Channel_99',
#   'main_frequency_Channel_100',
#   'main_frequency_Channel_101',
#   'main_frequency_Channel_102',
#   'main_frequency_Channel_103',
#   'main_frequency_Channel_104',
#   'main_frequency_Channel_105',
#   'main_frequency_Channel_106',
#   'main_frequency_Channel_107',
#   'main_frequency_Channel_108',
#   'main_frequency_Channel_109',
#   'main_frequency_Channel_110',
#   'main_frequency_Channel_111',
#   'main_frequency_Channel_112',
#   'main_frequency_Channel_113',
#   'main_frequency_Channel_114',
#   'main_frequency_Channel_115',
#   'main_frequency_Channel_116',
#   'main_frequency_Channel_117',
#   'main_frequency_Channel_118',
#   'main_frequency_Channel_119',
#   'main_frequency_Channel_120',
#   'main_frequency_Channel_121',
#   'main_frequency_Channel_122',
#   'main_frequency_Channel_123',
#   'main_frequency_Channel_124',
#   'main_frequency_Channel_125',
#   'main_frequency_Channel_126',
#   'main_frequency_Channel_127',
#   'main_frequency_Channel_128',
#   'main_frequency_Channel_129',
#   'main_frequency_Channel_130',
#   'main_frequency_Channel_131',
#   'main_frequency_Channel_132',
#   'main_frequency_Channel_133',
#   'main_frequency_Channel_134',
#   'main_frequency_Channel_135',
#   'main_frequency_Channel_136',
#   'main_frequency_Channel_137',
#   'main_frequency_Channel_138',
#   'main_frequency_Channel_139',
#   'main_frequency_Channel_140',
#   'main_frequency_Channel_141',
#   'main_frequency_Channel_142',
#   'main_frequency_Channel_143',
#   'main_frequency_Channel_144',
#   'main_frequency_Channel_145',
#   'main_frequency_Channel_146',
#   'main_frequency_Channel_147',
#   'main_frequency_Channel_148',
#   'main_frequency_Channel_149',
#   'main_frequency_Channel_150',
#   'main_frequency_Channel_151',
#   'main_frequency_Channel_152',
#   'main_frequency_Channel_153',
#   'main_frequency_Channel_154',
#   'main_frequency_Channel_155',
#   'main_frequency_Channel_156',
#   'main_frequency_Channel_157',
#   'main_frequency_Channel_158',
#   'main_frequency_Channel_159',
#   'main_frequency_Channel_160',
#   'main_frequency_Channel_161',
#   'main_frequency_Channel_162',
#   'main_frequency_Channel_163',
#   'main_frequency_Channel_164',
#   'main_frequency_Channel_165',
#   'main_frequency_Channel_166',
#   'main_frequency_Channel_167',
#   'main_frequency_Channel_168',
#   'main_frequency_Channel_169',
#   'main_frequency_Channel_170',
#   'main_frequency_Channel_171',
#   'main_frequency_Channel_172',
#   'main_frequency_Channel_173',
#   'main_frequency_Channel_174',
#   'main_frequency_Channel_175',
#   'main_frequency_Channel_176',
#   'main_frequency_Channel_177',
#   'main_frequency_Channel_178',
#   'main_frequency_Channel_179',
#   'main_frequency_Channel_180',
#   'main_frequency_Channel_181',
#   'main_frequency_Channel_182',
#   'main_frequency_Channel_183',
#   'main_frequency_Channel_184',
#   'main_frequency_Channel_185',
#   'main_frequency_Channel_186',
#   'main_frequency_Channel_187',
#   'main_frequency_Channel_188',
#   'main_frequency_Channel_189',
#   'main_frequency_Channel_190',
#   'main_frequency_Channel_191',
#   'main_frequency_Channel_192',
#   'main_frequency_Channel_193',
#   'main_frequency_Channel_194',
#   'main_frequency_Channel_195',
#   'main_frequency_Channel_196',
#   'main_frequency_Channel_197',
#   'main_frequency_Channel_198',
#   'main_frequency_Channel_199',
#   'main_frequency_Channel_200',
#   'main_frequency_Channel_201',
#   'main_frequency_Channel_202',
#   'main_frequency_Channel_203',
#   'main_frequency_Channel_204',
#   'main_frequency_Channel_205',
#   'main_frequency_Channel_206',
#   'main_frequency_Channel_207',
#   'main_frequency_Channel_208',
#   'main_frequency_Channel_209',
#   'main_frequency_Channel_210',
#   'main_frequency_Channel_211',
#   'main_frequency_Channel_212',
#   'main_frequency_Channel_213',
#   'main_frequency_Channel_214',
#   'main_frequency_Channel_215',
#   'main_frequency_Channel_216',
#   'main_frequency_Channel_217',
#   'main_frequency_Channel_218',
#   'main_frequency_Channel_219',
#   'main_frequency_Channel_220',
#   'main_frequency_Channel_221',
#   'main_frequency_Channel_222',
#   'main_frequency_Channel_223',
#   'main_frequency_Channel_224',
#   'main_frequency_Channel_225',
#   'main_frequency_Channel_226',
#   'main_frequency_Channel_227',
#   'main_frequency_Channel_228',
#   'main_frequency_Channel_229',
#   'main_frequency_Channel_230',
#   'main_frequency_Channel_231',
#   'main_frequency_Channel_232',
#   'main_frequency_Channel_233',
#   'main_frequency_Channel_234',
#   'main_frequency_Channel_235',
#   'main_frequency_Channel_236',
#   'main_frequency_Channel_237',
#   'main_frequency_Channel_238',
#   'main_frequency_Channel_239',
#   'main_frequency_Channel_240',
#   'main_frequency_Channel_241',
#   'main_frequency_Channel_242',
#   'main_frequency_Channel_243',
#   'main_frequency_Channel_244',
#   'main_frequency_Channel_245',
#   'main_frequency_Channel_246',
#   'main_frequency_Channel_247',
#   'main_frequency_Channel_248',
#   'main_frequency_Channel_249',
#   'main_frequency_Channel_250',
#   'main_frequency_Channel_251',
#   'main_frequency_Channel_252',
#   'main_frequency_Channel_253',
#   'main_frequency_Channel_254',
#   'main_frequency_Channel_255',
#   'main_frequency_Channel_256',
#   'main_frequency_Channel_257',
#   'main_frequency_Channel_258',
#   'main_frequency_Channel_259',
#   'main_frequency_Channel_260',
#   'main_frequency_Channel_261',
#   'main_frequency_Channel_262',
#   'main_frequency_Channel_263',
#   'main_frequency_Channel_264',
#   'main_frequency_Channel_265',
#   'main_frequency_Channel_266',
#   'main_frequency_Channel_267',
#   'main_frequency_Channel_268',
#   'main_frequency_Channel_269',
#   'main_frequency_Channel_270',
#   'main_frequency_Channel_271',
#   'main_frequency_Channel_272',
#   'main_frequency_Channel_273',
#   'main_frequency_Channel_274'],
#  'phase_congruency': ['phase_congruency_Channel_1',
#   'phase_congruency_Channel_2',
#   'phase_congruency_Channel_3',
#   'phase_congruency_Channel_4',
#   'phase_congruency_Channel_5',
#   'phase_congruency_Channel_6',
#   'phase_congruency_Channel_7',
#   'phase_congruency_Channel_8',
#   'phase_congruency_Channel_9',
#   'phase_congruency_Channel_10',
#   'phase_congruency_Channel_11',
#   'phase_congruency_Channel_12',
#   'phase_congruency_Channel_13',
#   'phase_congruency_Channel_14',
#   'phase_congruency_Channel_15',
#   'phase_congruency_Channel_16',
#   'phase_congruency_Channel_17',
#   'phase_congruency_Channel_18',
#   'phase_congruency_Channel_19',
#   'phase_congruency_Channel_20',
#   'phase_congruency_Channel_21',
#   'phase_congruency_Channel_22',
#   'phase_congruency_Channel_23',
#   'phase_congruency_Channel_24',
#   'phase_congruency_Channel_25',
#   'phase_congruency_Channel_26',
#   'phase_congruency_Channel_27',
#   'phase_congruency_Channel_28',
#   'phase_congruency_Channel_29',
#   'phase_congruency_Channel_30',
#   'phase_congruency_Channel_31',
#   'phase_congruency_Channel_32',
#   'phase_congruency_Channel_33',
#   'phase_congruency_Channel_34',
#   'phase_congruency_Channel_35',
#   'phase_congruency_Channel_36',
#   'phase_congruency_Channel_37',
#   'phase_congruency_Channel_38',
#   'phase_congruency_Channel_39',
#   'phase_congruency_Channel_40',
#   'phase_congruency_Channel_41',
#   'phase_congruency_Channel_42',
#   'phase_congruency_Channel_43',
#   'phase_congruency_Channel_44',
#   'phase_congruency_Channel_45',
#   'phase_congruency_Channel_46',
#   'phase_congruency_Channel_47',
#   'phase_congruency_Channel_48',
#   'phase_congruency_Channel_49',
#   'phase_congruency_Channel_50',
#   'phase_congruency_Channel_51',
#   'phase_congruency_Channel_52',
#   'phase_congruency_Channel_53',
#   'phase_congruency_Channel_54',
#   'phase_congruency_Channel_55',
#   'phase_congruency_Channel_56',
#   'phase_congruency_Channel_57',
#   'phase_congruency_Channel_58',
#   'phase_congruency_Channel_59',
#   'phase_congruency_Channel_60',
#   'phase_congruency_Channel_61',
#   'phase_congruency_Channel_62',
#   'phase_congruency_Channel_63',
#   'phase_congruency_Channel_64',
#   'phase_congruency_Channel_65',
#   'phase_congruency_Channel_66',
#   'phase_congruency_Channel_67',
#   'phase_congruency_Channel_68',
#   'phase_congruency_Channel_69',
#   'phase_congruency_Channel_70',
#   'phase_congruency_Channel_71',
#   'phase_congruency_Channel_72',
#   'phase_congruency_Channel_73',
#   'phase_congruency_Channel_74',
#   'phase_congruency_Channel_75',
#   'phase_congruency_Channel_76',
#   'phase_congruency_Channel_77',
#   'phase_congruency_Channel_78',
#   'phase_congruency_Channel_79',
#   'phase_congruency_Channel_80',
#   'phase_congruency_Channel_81',
#   'phase_congruency_Channel_82',
#   'phase_congruency_Channel_83',
#   'phase_congruency_Channel_84',
#   'phase_congruency_Channel_85',
#   'phase_congruency_Channel_86',
#   'phase_congruency_Channel_87',
#   'phase_congruency_Channel_88',
#   'phase_congruency_Channel_89',
#   'phase_congruency_Channel_90',
#   'phase_congruency_Channel_91',
#   'phase_congruency_Channel_92',
#   'phase_congruency_Channel_93',
#   'phase_congruency_Channel_94',
#   'phase_congruency_Channel_95',
#   'phase_congruency_Channel_96',
#   'phase_congruency_Channel_97',
#   'phase_congruency_Channel_98',
#   'phase_congruency_Channel_99',
#   'phase_congruency_Channel_100',
#   'phase_congruency_Channel_101',
#   'phase_congruency_Channel_102',
#   'phase_congruency_Channel_103',
#   'phase_congruency_Channel_104',
#   'phase_congruency_Channel_105',
#   'phase_congruency_Channel_106',
#   'phase_congruency_Channel_107',
#   'phase_congruency_Channel_108',
#   'phase_congruency_Channel_109',
#   'phase_congruency_Channel_110',
#   'phase_congruency_Channel_111',
#   'phase_congruency_Channel_112',
#   'phase_congruency_Channel_113',
#   'phase_congruency_Channel_114',
#   'phase_congruency_Channel_115',
#   'phase_congruency_Channel_116',
#   'phase_congruency_Channel_117',
#   'phase_congruency_Channel_118',
#   'phase_congruency_Channel_119',
#   'phase_congruency_Channel_120',
#   'phase_congruency_Channel_121',
#   'phase_congruency_Channel_122',
#   'phase_congruency_Channel_123',
#   'phase_congruency_Channel_124',
#   'phase_congruency_Channel_125',
#   'phase_congruency_Channel_126',
#   'phase_congruency_Channel_127',
#   'phase_congruency_Channel_128',
#   'phase_congruency_Channel_129',
#   'phase_congruency_Channel_130',
#   'phase_congruency_Channel_131',
#   'phase_congruency_Channel_132',
#   'phase_congruency_Channel_133',
#   'phase_congruency_Channel_134',
#   'phase_congruency_Channel_135',
#   'phase_congruency_Channel_136',
#   'phase_congruency_Channel_137',
#   'phase_congruency_Channel_138',
#   'phase_congruency_Channel_139',
#   'phase_congruency_Channel_140',
#   'phase_congruency_Channel_141',
#   'phase_congruency_Channel_142',
#   'phase_congruency_Channel_143',
#   'phase_congruency_Channel_144',
#   'phase_congruency_Channel_145',
#   'phase_congruency_Channel_146',
#   'phase_congruency_Channel_147',
#   'phase_congruency_Channel_148',
#   'phase_congruency_Channel_149',
#   'phase_congruency_Channel_150',
#   'phase_congruency_Channel_151',
#   'phase_congruency_Channel_152',
#   'phase_congruency_Channel_153',
#   'phase_congruency_Channel_154',
#   'phase_congruency_Channel_155',
#   'phase_congruency_Channel_156',
#   'phase_congruency_Channel_157',
#   'phase_congruency_Channel_158',
#   'phase_congruency_Channel_159',
#   'phase_congruency_Channel_160',
#   'phase_congruency_Channel_161',
#   'phase_congruency_Channel_162',
#   'phase_congruency_Channel_163',
#   'phase_congruency_Channel_164',
#   'phase_congruency_Channel_165',
#   'phase_congruency_Channel_166',
#   'phase_congruency_Channel_167',
#   'phase_congruency_Channel_168',
#   'phase_congruency_Channel_169',
#   'phase_congruency_Channel_170',
#   'phase_congruency_Channel_171',
#   'phase_congruency_Channel_172',
#   'phase_congruency_Channel_173',
#   'phase_congruency_Channel_174',
#   'phase_congruency_Channel_175',
#   'phase_congruency_Channel_176',
#   'phase_congruency_Channel_177',
#   'phase_congruency_Channel_178',
#   'phase_congruency_Channel_179',
#   'phase_congruency_Channel_180',
#   'phase_congruency_Channel_181',
#   'phase_congruency_Channel_182',
#   'phase_congruency_Channel_183',
#   'phase_congruency_Channel_184',
#   'phase_congruency_Channel_185',
#   'phase_congruency_Channel_186',
#   'phase_congruency_Channel_187',
#   'phase_congruency_Channel_188',
#   'phase_congruency_Channel_189',
#   'phase_congruency_Channel_190',
#   'phase_congruency_Channel_191',
#   'phase_congruency_Channel_192',
#   'phase_congruency_Channel_193',
#   'phase_congruency_Channel_194',
#   'phase_congruency_Channel_195',
#   'phase_congruency_Channel_196',
#   'phase_congruency_Channel_197',
#   'phase_congruency_Channel_198',
#   'phase_congruency_Channel_199',
#   'phase_congruency_Channel_200',
#   'phase_congruency_Channel_201',
#   'phase_congruency_Channel_202',
#   'phase_congruency_Channel_203',
#   'phase_congruency_Channel_204',
#   'phase_congruency_Channel_205',
#   'phase_congruency_Channel_206',
#   'phase_congruency_Channel_207',
#   'phase_congruency_Channel_208',
#   'phase_congruency_Channel_209',
#   'phase_congruency_Channel_210',
#   'phase_congruency_Channel_211',
#   'phase_congruency_Channel_212',
#   'phase_congruency_Channel_213',
#   'phase_congruency_Channel_214',
#   'phase_congruency_Channel_215',
#   'phase_congruency_Channel_216',
#   'phase_congruency_Channel_217',
#   'phase_congruency_Channel_218',
#   'phase_congruency_Channel_219',
#   'phase_congruency_Channel_220',
#   'phase_congruency_Channel_221',
#   'phase_congruency_Channel_222',
#   'phase_congruency_Channel_223',
#   'phase_congruency_Channel_224',
#   'phase_congruency_Channel_225',
#   'phase_congruency_Channel_226',
#   'phase_congruency_Channel_227',
#   'phase_congruency_Channel_228',
#   'phase_congruency_Channel_229',
#   'phase_congruency_Channel_230',
#   'phase_congruency_Channel_231',
#   'phase_congruency_Channel_232',
#   'phase_congruency_Channel_233',
#   'phase_congruency_Channel_234',
#   'phase_congruency_Channel_235',
#   'phase_congruency_Channel_236',
#   'phase_congruency_Channel_237',
#   'phase_congruency_Channel_238',
#   'phase_congruency_Channel_239',
#   'phase_congruency_Channel_240',
#   'phase_congruency_Channel_241',
#   'phase_congruency_Channel_242',
#   'phase_congruency_Channel_243',
#   'phase_congruency_Channel_244',
#   'phase_congruency_Channel_245',
#   'phase_congruency_Channel_246',
#   'phase_congruency_Channel_247',
#   'phase_congruency_Channel_248',
#   'phase_congruency_Channel_249',
#   'phase_congruency_Channel_250',
#   'phase_congruency_Channel_251',
#   'phase_congruency_Channel_252',
#   'phase_congruency_Channel_253',
#   'phase_congruency_Channel_254',
#   'phase_congruency_Channel_255',
#   'phase_congruency_Channel_256',
#   'phase_congruency_Channel_257',
#   'phase_congruency_Channel_258',
#   'phase_congruency_Channel_259',
#   'phase_congruency_Channel_260',
#   'phase_congruency_Channel_261',
#   'phase_congruency_Channel_262',
#   'phase_congruency_Channel_263',
#   'phase_congruency_Channel_264',
#   'phase_congruency_Channel_265',
#   'phase_congruency_Channel_266',
#   'phase_congruency_Channel_267',
#   'phase_congruency_Channel_268',
#   'phase_congruency_Channel_269',
#   'phase_congruency_Channel_270',
#   'phase_congruency_Channel_271',
#   'phase_congruency_Channel_272',
#   'phase_congruency_Channel_273',
#   'phase_congruency_Channel_274']}
